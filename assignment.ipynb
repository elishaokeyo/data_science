# %%
import pandas

# %%
import pandas
# Out:
# Failed to start the Kernel.
#
# Unable to start Kernel 'Python 3.11.9' due to a timeout waiting for the ports to get used.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import pandas
# import data 
data=pandas.read_csv("data/sales.csv")
# read data 
data
# Out:
#                               name       sku category  quantity  unit price  \
# 0                      Carroll PLC  QN-82852     Belt        13       44.48
# 1                Heidenreich-Bosco  MJ-21460    Shoes        19       53.62
# 2    Kerluke, Reilly and Bechtelar  AS-93055    Shirt        12       24.16
# 3                    Waters-Walker  AS-93055    Shirt         5       82.68
# 4                    Waelchi-Fahey  AS-93055    Shirt        18       99.64
# ..                             ...       ...      ...       ...         ...
# 995      Kihn, McClure and Denesik  WJ-02096     Belt        11       60.50
# 996                      Kunze Inc  GS-86623    Shoes        16       19.66
# 997                  Waters-Walker  GS-86623    Shoes        13       90.95
# 998                      Huel-Haag  LL-46261    Shoes         9       98.22
# 999              Heidenreich-Bosco  LW-86841    Shoes        14       74.83
#
#      ext price                 date
# ...

# %%
data.isnull().sum()
# Out:
# name          0
# sku           0
# category      0
# quantity      0
# unit price    0
# ext price     0
# date          0
# dtype: int64

# %%
data["quantity"].mean()
# Out:
# 10.328

# %%
data["unit price"].mean()
# Out:
# 56.179629999999996

# %%
data["ext price"].mean()
# Out:
# 579.8439000000002

# %%
data["quantity"].min()
# Out:
# 1

# %%
data["unit price"].min()
# Out:
# 10.06

# %%
data["ext price"].min()
# Out:
# 10.38

# %%
data["quantity"].max()
# Out:
# 20

# %%
data["unit price"].max()
# Out:
# 99.97

# %%
data["ext price"].max()
# Out:
# 1994.8

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.available
plt.style.use('seaborn-v0_8')

# %%
data.groupby("category").size()
# Out:
# category
# Belt     196
# Shirt    404
# Shoes    400
# dtype: int64

# %%
sns.countplot(x=data["category"], palette="magma")
# Out:
# /tmp/ipykernel_2327/3948289489.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=data["category"], palette="magma")
# <Axes: xlabel='category', ylabel='count'>

# %%
sns.scatterplot
colors=["#3949AB", "#2E7D32", "#546E7A"]
sns.scatterplot(x=data["category"], y="unit price", data=data ,palette="Greens", hue="category")
# Out:
# <Axes: xlabel='category', ylabel='unit price'>

# %%
sns.barplot
colors=["#3949AB", "#2E7D32", "#546E7A"]
sns.barplot(x=data["category"], y="unit price",data=data, palette="magma", hue="category")
plt.title("unit price in relation to category")
# Out:
# Text(0.5, 1.0, 'unit price in relation to category')

# %%
sns.swarmplot
colors=["#3949AB", "#2E7D32", "#546E7A"]
sns.swarmplot(x=data["category"], y="ext price",data=data, palette="magma", hue="category")
plt.title("distribution of ext price in relation to category")
# Out:
# Text(0.5, 1.0, 'distribution of ext price in relation to category')

# %%
data.groupby("category").size().plot(kind="pie", autopct="%1.1f%%")
plt.title("distribution of category")
# Out:
# Text(0.5, 1.0, 'distribution of category')
